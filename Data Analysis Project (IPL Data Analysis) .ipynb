# %%
# EDA

# %%
# IPL data analysis

# %% [markdown]
# ![image.png](attachment:83cf8258-00fa-4f8c-a87f-961d65255f72.png)

# %% [markdown]
# Introduction
# This project involves conducting Exploratory Data Analysis (EDA) on the Indian Premier League (IPL) dataset. The dataset encompasses a wide range of information about IPL matches, teams, players, venues, and more. The primary objective of this analysis is to uncover insights into the most successful teams, players, and factors influencing the outcomes of matches.
#
#
# Exploratory Data Analysis (EDA): This project focuses on conducting exploratory data analysis to gain insights from the dataset and understand trends, patterns, and relationships between various variables.
#
# Identify Successful Teams and Players: By analyzing match outcomes, we aim to identify the most successful teams and players over the years.
#
# Factors Influencing Wins and Losses: We'll explore the factors that contribute to a team's win or loss, including the impact of toss decisions, batting first vs. batting second, and more.
#
# Endorsement Suggestions: Based on player performance and popularity, we'll suggest teams or players that a company could potentially consider endorsing for its products.
#
#
# The dataset used for this analysis consists of two main data files:
#
# Matches Dataset: This dataset includes information about each IPL match, such as teams, date, venue, toss details, match result, and more.
#
# Deliveries Dataset: This dataset provides detailed information about deliveries in each match,
# including batting and bowling information, runs scored, wickets taken, and more.

# %% [raw]
# Libraries and Tools Used
# Pandas: Data manipulation and analysis
# NumPy: Mathematical operations
# Matplotlib: Data visualization
# Seaborn: Enhanced data visualization
# Jupyter Notebook: Interactive coding environment

# %%
# Project steps

# %% [raw]
# Data Loading and Preprocessing: Load the matches and deliveries datasets, examine their structure, handle missing values, and perform initial data preprocessing.
#
# Exploratory Data Analysis (EDA): Conduct exploratory data analysis to understand the distribution of various variables, visualize trends, and generate insights.
#
# Seasonal Analysis: Analyze the number of matches played each season and the number of teams participating to identify trends and changes over the years.
#
# Toss Analysis: Study the impact of winning the toss on match outcomes, including the choice to bat or field first.
#
# Player Performance: Identify players who have consistently performed well, both in terms of batting and bowling.
#
# Venue Analysis: Analyze the impact of different venues on match results and team strategies.
#
# Decision Making: Explore the effects of different decisions made by teams after winning the toss, such as choosing to bat or field first.
#
# Batting and Bowling Analysis: Analyze the performance of top batsmen and bowlers based on runs scored and wickets taken.
#
# Consistency Analysis: Examine the consistency of players' performance over different seasons.
#
# Winning Factors: Identify factors contributing to team wins and losses, such as batting second advantage and winning margins.
#
# Endorsement Suggestions: Based on player popularity and performance, suggest potential teams or players for endorsement opportunities.

# %% [markdown]
# ### **Note :**
# * You will need the below 3 datasets to work on the questions :
#   * **ipl_matches.csv**
#   * **ipl_batting.csv**
#   * **ipl_deliveries.csv**

# %%
# importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading datasets
batting = pd.read_csv("ipl_batting.csv")
deliveries = pd.read_csv("ipl_deliveries.csv")
matches = pd.read_csv("ipl_matches.csv")

# %%
batting.shape
# Out:
# (11546, 17)

# %%
deliveries.shape
# Out:
# (150460, 14)

# %%
matches.shape
# Out:
# (763, 13)

# %%
batting
# Out:
#         match_no               team_1               team_2        batsmen  \
# 0              1       Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1              1       Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2              1       Mumbai Indians  Chennai Super Kings       S Dhawan
# 3              1       Mumbai Indians  Chennai Super Kings      JP Duminy
# 4              1       Mumbai Indians  Chennai Super Kings       DJ Bravo
# ...          ...                  ...                  ...            ...
# 11541  Final (N)  Chennai Super Kings     Rajasthan Royals      YK Pathan
# 11542  Final (N)  Chennai Super Kings     Rajasthan Royals         M Kaif
# 11543  Final (N)  Chennai Super Kings     Rajasthan Royals      RA Jadeja
# 11544  Final (N)  Chennai Super Kings     Rajasthan Royals       SK Warne
# 11545  Final (N)  Chennai Super Kings     Rajasthan Royals  Sohail Tanvir
#
#                     wicket_status     R     B    M  fours  sixes      SR  \
# ...

# %%
batting.columns
# Out:
# Index(['match_no', 'team_1', 'team_2', 'batsmen', 'wicket_status', 'R', 'B',
#        'M', 'fours', 'sixes', 'SR', 'special_role', 'dismissal_mode',
#        'bowler_name', 'fielder', 'is_fielder_involved', 'match_date'],
#       dtype='object')

# %%
batting.match_date
# Out:
# 0        2009-04-18
# 1        2009-04-18
# 2        2009-04-18
# 3        2009-04-18
# 4        2009-04-18
#             ...
# 11541    2008-06-01
# 11542    2008-06-01
# 11543    2008-06-01
# 11544    2008-06-01
# 11545    2008-06-01
# Name: match_date, Length: 11546, dtype: object

# %%
batting.dtypes
# Out:
# match_no                object
# team_1                  object
# team_2                  object
# batsmen                 object
# wicket_status           object
# R                      float64
# B                      float64
# M                      float64
# fours                  float64
# sixes                  float64
# SR                     float64
# special_role            object
# dismissal_mode          object
# bowler_name             object
# fielder                 object
# is_fielder_involved      int64
# match_date              object
# dtype: object

# %%
# match_date column >> data type is wrong

# %%
batting['match_no'].value_counts()
# Out:
# match_no
# 1                  268
# Final (N)          179
# 21                 179
# 41                 173
# 51                 173
#                   ...
# 47th match          11
# 8th Match (N)       11
# 56th Match (N)      11
# 2nd Match (D/N)     11
# 28th Match (N)      10
# Name: count, Length: 210, dtype: int64

# %%
batting['special_role'].value_counts()
# Out:
# special_role
# normal player              9107
# captain                    1088
# wicket keeper              1061
# captain & wicket keeper     290
# Name: count, dtype: int64

# %%
# deliveries.shape

# %%
deliveries.shape
# Out:
# (150460, 14)

# %%
deliveries
# Out:
#           Match_id      Innings  Over  Delivery       Batsman         Bowler  \
# 0       2016043001  1st innings     1       0.1     DA Warner  KW Richardson
# 1       2016043001  1st innings     1       0.2     DA Warner  KW Richardson
# 2       2016043001  1st innings     1       0.3     DA Warner  KW Richardson
# 3       2016043001  1st innings     1       0.4      S Dhawan  KW Richardson
# 4       2016043001  1st innings     1       0.5      S Dhawan  KW Richardson
# ...            ...          ...   ...       ...           ...            ...
# 150455  2011051602  2nd innings    19      18.4  DT Christian   Yuvraj Singh
# 150456  2011051602  2nd innings    19      18.5  DT Christian   Yuvraj Singh
# 150457  2011051602  2nd innings    19      18.6  DT Christian   Yuvraj Singh
# 150458  2011051602  2nd innings    20      19.1  DT Christian     WD Parnell
# 150459  2011051602  2nd innings    20      19.2      B Chipli     WD Parnell
#
# ...

# %%
deliveries.columns
# Out:
# Index(['Match_id', 'Innings', 'Over', 'Delivery', 'Batsman', 'Bowler',
#        'non_striker', 'runs_batsman', 'runs_extras', 'extras_type',
#        'Runs_total', 'player_out', 'mode_of_dismissal', 'fielders_involved'],
#       dtype='object')

# %%
deliveries.dtypes
# Out:
# Match_id               int64
# Innings               object
# Over                   int64
# Delivery             float64
# Batsman               object
# Bowler                object
# non_striker           object
# runs_batsman           int64
# runs_extras            int64
# extras_type           object
# Runs_total             int64
# player_out            object
# mode_of_dismissal     object
# fielders_involved     object
# dtype: object

# %%
# matches

# %%
matches.shape
# Out:
# (763, 13)

# %%
matches
# Out:
#      match_date                Ground                       Team 1  \
# 0    2008-04-18  Bengaluru, Bangalore  Royal Challengers Bangalore
# 1    2008-04-19    Mohali, Chandigarh              Kings XI Punjab
# 2    2008-04-19                 Delhi               Delhi Capitals
# 3    2008-04-20               Kolkata        Kolkata Knight Riders
# 4    2008-04-20                Mumbai               Mumbai Indians
# ..          ...                   ...                          ...
# 758  2019-05-05                Mumbai               Mumbai Indians
# 759  2019-05-07               Chennai               Mumbai Indians
# 760  2019-05-08         Visakhapatnam               Delhi Capitals
# 761  2019-05-10         Visakhapatnam          Chennai Super Kings
# 762  2019-05-12    Hyderabad (Deccan)               Mumbai Indians
#
#                           Team 2                       Winner  year  month  \
# 0          Kolkata Knight Riders        Kolkata Knight Riders  2008      4
# ...

# %%
#match_date >> data type is wrong

# %% [markdown]
#  ### **Question 1**
# Write **Python** code for the following
# * Read the **ipl_matches.csv** dataset
# * Display **data-type** of each column
# * Define **granularity** for the dataset **ipl_matches**
# * Write code to create a **primary key** as a **new column** for the dataset
#   * Convert match_date into the format **YYYYMMDD**
#   * Depending upon whether the given match is the **1st** of **2nd** for the day, append a string **01 or 02** to the end
#   * **Ex.** if 2 matches took place on 18-04-2009 then the primary key of the 1st match should look like **2009041801** and second match as **2009041802**
# --------------------

# %%
matches.dtypes
# Out:
# match_date        object
# Ground            object
# Team 1            object
# Team 2            object
# Winner            object
# year               int64
# month              int64
# day                int64
# win_mode          object
# margin           float64
# toss_winner       object
# toss_decision     object
# match_no           int64
# dtype: object

# %%
date = matches.match_date
key = []
visited = []
for i in date:
    if i in visited:
        number = visited.count(i)
        temp = i.split('-')
        temp1 = temp[0]+temp[1]+temp[2]+'0'+str(number+1)
        visited.append(i)
        key.append(temp1)
    else:
        temp = i.split('-')
        temp1 = temp[0]+temp[1]+temp[2]+'01'
        key.append(temp1)
        visited.append(i)

# %%
matches
# Out:
#      match_date                Ground                       Team 1  \
# 0    2008-04-18  Bengaluru, Bangalore  Royal Challengers Bangalore
# 1    2008-04-19    Mohali, Chandigarh              Kings XI Punjab
# 2    2008-04-19                 Delhi               Delhi Capitals
# 3    2008-04-20               Kolkata        Kolkata Knight Riders
# 4    2008-04-20                Mumbai               Mumbai Indians
# ..          ...                   ...                          ...
# 758  2019-05-05                Mumbai               Mumbai Indians
# 759  2019-05-07               Chennai               Mumbai Indians
# 760  2019-05-08         Visakhapatnam               Delhi Capitals
# 761  2019-05-10         Visakhapatnam          Chennai Super Kings
# 762  2019-05-12    Hyderabad (Deccan)               Mumbai Indians
#
#                           Team 2                       Winner  year  month  \
# 0          Kolkata Knight Riders        Kolkata Knight Riders  2008      4
# ...

# %%
matches['match_key']= key

# %%
matches.head()
# Out:
#    match_date                Ground                       Team 1  \
# 0  2008-04-18  Bengaluru, Bangalore  Royal Challengers Bangalore
# 1  2008-04-19    Mohali, Chandigarh              Kings XI Punjab
# 2  2008-04-19                 Delhi               Delhi Capitals
# 3  2008-04-20               Kolkata        Kolkata Knight Riders
# 4  2008-04-20                Mumbai               Mumbai Indians
#
#                         Team 2                       Winner  year  month  day  \
# 0        Kolkata Knight Riders        Kolkata Knight Riders  2008      4   18
# 1          Chennai Super Kings          Chennai Super Kings  2008      4   19
# 2             Rajasthan Royals               Delhi Capitals  2008      4   19
# 3              Deccan Chargers        Kolkata Knight Riders  2008      4   20
# 4  Royal Challengers Bangalore  Royal Challengers Bangalore  2008      4   20
#
#   win_mode  margin                  toss_winner toss_decision  match_no  \
# ...

# %%
matches.columns
# Out:
# Index(['match_date', 'Ground', 'Team 1', 'Team 2', 'Winner', 'year', 'month',
#        'day', 'win_mode', 'margin', 'toss_winner', 'toss_decision', 'match_no',
#        'match_key'],
#       dtype='object')

# %%
matches=matches[['match_key','match_date', 'Ground', 'Team 1', 'Team 2', 'Winner', 'year', 'month',
       'day', 'win_mode', 'margin', 'toss_winner', 'toss_decision','match_no',]]

# %%
matches
# Out:
#       match_key  match_date                Ground  \
# 0    2008041801  2008-04-18  Bengaluru, Bangalore
# 1    2008041901  2008-04-19    Mohali, Chandigarh
# 2    2008041902  2008-04-19                 Delhi
# 3    2008042001  2008-04-20               Kolkata
# 4    2008042002  2008-04-20                Mumbai
# ..          ...         ...                   ...
# 758  2019050502  2019-05-05                Mumbai
# 759  2019050701  2019-05-07               Chennai
# 760  2019050801  2019-05-08         Visakhapatnam
# 761  2019051001  2019-05-10         Visakhapatnam
# 762  2019051201  2019-05-12    Hyderabad (Deccan)
#
#                           Team 1                       Team 2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2                 Delhi Capitals             Rajasthan Royals
# 3          Kolkata Knight Riders              Deccan Chargers
# ...

# %% [markdown]
# ### **Question 2**
# Let's look at the below statement : <br>
# **It is said that you win half the match if you win the toss** <br><br>
# So, let's understand to what extent teams who **won the toss** also **won the matches**
#   * Write code to find out **% matches by team** (across all seasons) where they **won the toss**
#   * What **% of matches** which the teams **won the toss also ended up winning the matches**?
#   * Exhibit the above as a **% of total matches**
#   * Which team tops the chart? Meaning which team took full advantage of the opportunity of winning the toss
#
# **Ex :** If CSK played a total of **100** matches and won toss in **70** of them. This would mean **70%** of tosses were won by them. Now,
# if out of these 70 they ended up winning **28** of them then they won **40%**of the matches where they had won the toss. This is **28%** of
# total matches

# %%
matches.columns
# Out:
# Index(['match_key', 'match_date', 'Ground', 'Team 1', 'Team 2', 'Winner',
#        'year', 'month', 'day', 'win_mode', 'margin', 'toss_winner',
#        'toss_decision', 'match_no'],
#       dtype='object')

# %%
matches['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Delhi Capitals                 90
# Chennai Super Kings            89
# Royal Challengers Bangalore    82
# Rajasthan Royals               80
# Kings XI Punjab                80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# no toss                         7
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
matches['toss_winner']=matches['toss_winner'].replace("Rising Pune Supergiants","Rising Pune Supergiant")

# %%
matches['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Delhi Capitals                 90
# Chennai Super Kings            89
# Royal Challengers Bangalore    82
# Rajasthan Royals               80
# Kings XI Punjab                80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiant         13
# Kochi Tuskers Kerala            8
# no toss                         7
# Name: count, dtype: int64

# %%
matches
# Out:
#       match_key  match_date                Ground  \
# 0    2008041801  2008-04-18  Bengaluru, Bangalore
# 1    2008041901  2008-04-19    Mohali, Chandigarh
# 2    2008041902  2008-04-19                 Delhi
# 3    2008042001  2008-04-20               Kolkata
# 4    2008042002  2008-04-20                Mumbai
# ..          ...         ...                   ...
# 758  2019050502  2019-05-05                Mumbai
# 759  2019050701  2019-05-07               Chennai
# 760  2019050801  2019-05-08         Visakhapatnam
# 761  2019051001  2019-05-10         Visakhapatnam
# 762  2019051201  2019-05-12    Hyderabad (Deccan)
#
#                           Team 1                       Team 2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2                 Delhi Capitals             Rajasthan Royals
# 3          Kolkata Knight Riders              Deccan Chargers
# ...

# %%
team_1=matches['Team 1'].groupby(matches['Team 1']).agg('count')

# %%
team_1
# Out:
# Team 1
# Chennai Super Kings             91
# Deccan Chargers                 39
# Delhi Capitals                  92
# Gujarat Lions                   16
# Kings XI Punjab                 87
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           87
# Mumbai Indians                  87
# Pune Warriors                   23
# Rajasthan Royals                66
# Rising Pune Supergiant          14
# Royal Challengers Bangalore    101
# Sunrisers Hyderabad             53
# Name: Team 1, dtype: int64

# %%
team_2=matches['Team 2'].groupby(matches['Team 2']).agg('count')

# %%
team_2
# Out:
# Team 2
# Chennai Super Kings             75
# Deccan Chargers                 37
# Delhi Capitals                  86
# Gujarat Lions                   14
# Kings XI Punjab                 88
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           94
# Mumbai Indians                 101
# Pune Warriors                   23
# Rajasthan Royals                84
# Rising Pune Supergiant          16
# Royal Challengers Bangalore     82
# Sunrisers Hyderabad             56
# Name: Team 2, dtype: int64

# %%
total_matches=team_1+team_2

# %%
total_matches
# Out:
# Team 1
# Chennai Super Kings            166
# Deccan Chargers                 76
# Delhi Capitals                 178
# Gujarat Lions                   30
# Kings XI Punjab                175
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          181
# Mumbai Indians                 188
# Pune Warriors                   46
# Rajasthan Royals               150
# Rising Pune Supergiant          30
# Royal Challengers Bangalore    183
# Sunrisers Hyderabad            109
# dtype: int64

# %%
toss_winner=matches['toss_winner'].groupby(matches['toss_winner']).agg('count')

# %%
toss_winner
# Out:
# toss_winner
# Chennai Super Kings            89
# Deccan Chargers                43
# Delhi Capitals                 90
# Gujarat Lions                  15
# Kings XI Punjab                80
# Kochi Tuskers Kerala            8
# Kolkata Knight Riders          92
# Mumbai Indians                 98
# Pune Warriors                  20
# Rajasthan Royals               80
# Rising Pune Supergiant         13
# Royal Challengers Bangalore    82
# Sunrisers Hyderabad            46
# no toss                         7
# Name: toss_winner, dtype: int64

# %%
percentage_winning_toss=(toss_winner/total_matches)*100

# %%
percentage_winning_toss
# Out:
# Chennai Super Kings            53.614458
# Deccan Chargers                56.578947
# Delhi Capitals                 50.561798
# Gujarat Lions                  50.000000
# Kings XI Punjab                45.714286
# Kochi Tuskers Kerala           57.142857
# Kolkata Knight Riders          50.828729
# Mumbai Indians                 52.127660
# Pune Warriors                  43.478261
# Rajasthan Royals               53.333333
# Rising Pune Supergiant         43.333333
# Royal Challengers Bangalore    44.808743
# Sunrisers Hyderabad            42.201835
# no toss                              NaN
# dtype: float64

# %%
match_winner=matches['Winner'].groupby(matches['Winner']).agg('count')

# %%
match_winner
# Out:
# Winner
# Chennai Super Kings            100
# Deccan Chargers                 29
# Delhi Capitals                  76
# Gujarat Lions                   13
# Kings XI Punjab                 80
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders           91
# Match                            2
# Mumbai Indians                 107
# Pune Warriors                   12
# Rajasthan Royals                73
# Rising Pune Supergiant          15
# Royal Challengers Bangalore     83
# Sunrisers Hyderabad             57
# abandoned                        6
# no result                        5
# tied                             8
# Name: Winner, dtype: int64

# %%
toss_match_winner=matches['Team 1'].groupby([matches['Winner'],matches['toss_winner']]).agg('count')

# %%
toss_match_winner
# Out:
# Winner               toss_winner
# Chennai Super Kings  Chennai Super Kings            57
#                      Deccan Chargers                 2
#                      Delhi Capitals                  7
#                      Kings XI Punjab                 3
#                      Kolkata Knight Riders           6
#                                                     ..
# tied                 Kings XI Punjab                 1
#                      Kolkata Knight Riders           1
#                      Mumbai Indians                  1
#                      Rajasthan Royals                1
#                      Royal Challengers Bangalore     2
# Name: Team 1, Length: 125, dtype: int64

# %%
temp= toss_match_winner.reset_index()

# %%
temp
# Out:
#                   Winner                  toss_winner  Team 1
# 0    Chennai Super Kings          Chennai Super Kings      57
# 1    Chennai Super Kings              Deccan Chargers       2
# 2    Chennai Super Kings               Delhi Capitals       7
# 3    Chennai Super Kings              Kings XI Punjab       3
# 4    Chennai Super Kings        Kolkata Knight Riders       6
# ..                   ...                          ...     ...
# 120                 tied              Kings XI Punjab       1
# 121                 tied        Kolkata Knight Riders       1
# 122                 tied               Mumbai Indians       1
# 123                 tied             Rajasthan Royals       1
# 124                 tied  Royal Challengers Bangalore       2
#
# [125 rows x 3 columns]

# %%
df=temp.loc[temp['Winner']==temp['toss_winner']]

# %%
df
# Out:
#                           Winner                  toss_winner  Team 1
# 0            Chennai Super Kings          Chennai Super Kings      57
# 11               Deccan Chargers              Deccan Chargers      19
# 19                Delhi Capitals               Delhi Capitals      41
# 29                 Gujarat Lions                Gujarat Lions      10
# 36               Kings XI Punjab              Kings XI Punjab      34
# 44          Kochi Tuskers Kerala         Kochi Tuskers Kerala       4
# 50         Kolkata Knight Riders        Kolkata Knight Riders      53
# 63                Mumbai Indians               Mumbai Indians      55
# 75                 Pune Warriors                Pune Warriors       3
# 84              Rajasthan Royals             Rajasthan Royals      41
# 89        Rising Pune Supergiant       Rising Pune Supergiant       8
# 103  Royal Challengers Bangalore  Royal Challengers Bangalore      40
# ...

# %%
# dif = toss_winner.to_numpy()

# %%
# dif

# %%
# dif = np.delete(dif,13)

# %%
# dif

# %%
df['Team']=toss_winner.drop('no toss').values
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\3911673449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Team']=toss_winner.drop('no toss').values

# %%
df.drop('Winner',inplace=True,axis=1)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\596980869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Winner',inplace=True,axis=1)

# %%
df
# Out:
#                      toss_winner  Team 1  Team
# 0            Chennai Super Kings      57    89
# 11               Deccan Chargers      19    43
# 19                Delhi Capitals      41    90
# 29                 Gujarat Lions      10    15
# 36               Kings XI Punjab      34    80
# 44          Kochi Tuskers Kerala       4     8
# 50         Kolkata Knight Riders      53    92
# 63                Mumbai Indians      55    98
# 75                 Pune Warriors       3    20
# 84              Rajasthan Royals      41    80
# 89        Rising Pune Supergiant       8    13
# 103  Royal Challengers Bangalore      40    82
# 113          Sunrisers Hyderabad      23    46

# %%
df.columns
# Out:
# Index(['toss_winner', 'Team 1', 'Team'], dtype='object')

# %%
df.columns = ['Team','Win+Toss','Toss']

# %%
df
# Out:
#                             Team  Win+Toss  Toss
# 0            Chennai Super Kings        57    89
# 11               Deccan Chargers        19    43
# 19                Delhi Capitals        41    90
# 29                 Gujarat Lions        10    15
# 36               Kings XI Punjab        34    80
# 44          Kochi Tuskers Kerala         4     8
# 50         Kolkata Knight Riders        53    92
# 63                Mumbai Indians        55    98
# 75                 Pune Warriors         3    20
# 84              Rajasthan Royals        41    80
# 89        Rising Pune Supergiant         8    13
# 103  Royal Challengers Bangalore        40    82
# 113          Sunrisers Hyderabad        23    46

# %%
df['%(win+toss)'] = (df['Win+Toss']/df['Toss'])*100
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\608232004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%(win+toss)'] = (df['Win+Toss']/df['Toss'])*100

# %%
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#                            Team  Win+Toss  Toss  %(win+toss)
# 0           Chennai Super Kings        57    89    64.044944
# 1               Deccan Chargers        19    43    44.186047
# 2                Delhi Capitals        41    90    45.555556
# 3                 Gujarat Lions        10    15    66.666667
# 4               Kings XI Punjab        34    80    42.500000
# 5          Kochi Tuskers Kerala         4     8    50.000000
# 6         Kolkata Knight Riders        53    92    57.608696
# 7                Mumbai Indians        55    98    56.122449
# 8                 Pune Warriors         3    20    15.000000
# 9              Rajasthan Royals        41    80    51.250000
# 10       Rising Pune Supergiant         8    13    61.538462
# 11  Royal Challengers Bangalore        40    82    48.780488
# 12          Sunrisers Hyderabad        23    46    50.000000

# %%
df['%toss']=percentage_winning_toss.drop('no toss').values
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\3476638613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%toss']=percentage_winning_toss.drop('no toss').values

# %%
df
# Out:
#                            Team  Win+Toss  Toss  %(win+toss)      %toss
# 0           Chennai Super Kings        57    89    64.044944  53.614458
# 1               Deccan Chargers        19    43    44.186047  56.578947
# 2                Delhi Capitals        41    90    45.555556  50.561798
# 3                 Gujarat Lions        10    15    66.666667  50.000000
# 4               Kings XI Punjab        34    80    42.500000  45.714286
# 5          Kochi Tuskers Kerala         4     8    50.000000  57.142857
# 6         Kolkata Knight Riders        53    92    57.608696  50.828729
# 7                Mumbai Indians        55    98    56.122449  52.127660
# 8                 Pune Warriors         3    20    15.000000  43.478261
# 9              Rajasthan Royals        41    80    51.250000  53.333333
# 10       Rising Pune Supergiant         8    13    61.538462  43.333333
# 11  Royal Challengers Bangalore        40    82    48.780488  44.808743
# ...

# %%
df['total_matches']=total_matches.values
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\1660091297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_matches']=total_matches.values

# %%
df
# Out:
#                            Team  Win+Toss  Toss  %(win+toss)      %toss  \
# 0           Chennai Super Kings        57    89    64.044944  53.614458
# 1               Deccan Chargers        19    43    44.186047  56.578947
# 2                Delhi Capitals        41    90    45.555556  50.561798
# 3                 Gujarat Lions        10    15    66.666667  50.000000
# 4               Kings XI Punjab        34    80    42.500000  45.714286
# 5          Kochi Tuskers Kerala         4     8    50.000000  57.142857
# 6         Kolkata Knight Riders        53    92    57.608696  50.828729
# 7                Mumbai Indians        55    98    56.122449  52.127660
# 8                 Pune Warriors         3    20    15.000000  43.478261
# 9              Rajasthan Royals        41    80    51.250000  53.333333
# 10       Rising Pune Supergiant         8    13    61.538462  43.333333
# 11  Royal Challengers Bangalore        40    82    48.780488  44.808743
# ...

# %%
df['%(win+toss)/total'] = (df['Win+Toss']/df['total_matches']) *100
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\2710437614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['%(win+toss)/total'] = (df['Win+Toss']/df['total_matches']) *100

# %%
df
# Out:
#                            Team  Win+Toss  Toss  %(win+toss)      %toss  \
# 0           Chennai Super Kings        57    89    64.044944  53.614458
# 1               Deccan Chargers        19    43    44.186047  56.578947
# 2                Delhi Capitals        41    90    45.555556  50.561798
# 3                 Gujarat Lions        10    15    66.666667  50.000000
# 4               Kings XI Punjab        34    80    42.500000  45.714286
# 5          Kochi Tuskers Kerala         4     8    50.000000  57.142857
# 6         Kolkata Knight Riders        53    92    57.608696  50.828729
# 7                Mumbai Indians        55    98    56.122449  52.127660
# 8                 Pune Warriors         3    20    15.000000  43.478261
# 9              Rajasthan Royals        41    80    51.250000  53.333333
# 10       Rising Pune Supergiant         8    13    61.538462  43.333333
# 11  Royal Challengers Bangalore        40    82    48.780488  44.808743
# ...

# %%
rainbow_colours=sns.color_palette('rainbow',len(df))

# %%
rainbow_colours
# Out:
# [(0.3588235294117647, 0.2199463578396686, 0.9938591368952737),
#  (0.21764705882352942, 0.42912060877260894, 0.9755119679804366),
#  (0.07647058823529412, 0.6172782212897929, 0.9451838281608196),
#  (0.0725490196078431, 0.7829276104921027, 0.9005867023006374),
#  (0.21372549019607845, 0.9005867023006374, 0.8469582108244671),
#  (0.3549019607843137, 0.9741386021045101, 0.7829276104921028),
#  (0.503921568627451, 0.9999810273487268, 0.7049255469061472),
#  (0.6450980392156862, 0.9741386021045102, 0.622112816721474),
#  (0.7862745098039214, 0.9005867023006376, 0.5316594672504363),
#  (0.9274509803921569, 0.7829276104921029, 0.43467642176596505),
#  (1.0, 0.6172782212897929, 0.3265387128400833),
#  (1.0, 0.42912060877260916, 0.2199463578396687),
#  (1.0, 0.21994635783966857, 0.11065268189150082)]

# %%
plt.figure(figsize=(10,10))
ax=sns.barplot(data=df,x='Team',y='Win+Toss',palette=rainbow_colours).set_xticklabels(df['Team'],rotation=90)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\2139235284.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df,x='Team',y='Win+Toss',palette=rainbow_colours).set_xticklabels(df['Team'],rotation=90)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\2139235284.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax=sns.barplot(data=df,x='Team',y='Win+Toss',palette=rainbow_colours).set_xticklabels(df['Team'],rotation=90)

# %%
df1=df[['Team','%(win+toss)/total']]
df1.sort_values(by='%(win+toss)/total',ascending=False,ignore_index=True,inplace=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\2495426608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.sort_values(by='%(win+toss)/total',ascending=False,ignore_index=True,inplace=True)

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(data=df1,x='Team',y='%(win+toss)/total', color='Yellow').set_xticklabels(df['Team'], rotation=90)
for i,j in enumerate(df1['%(win+toss)/total'].values):
    plt.text(i,j,str(round(j,2)),ha='center',va='bottom')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15868\855009076.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax=sns.barplot(data=df1,x='Team',y='%(win+toss)/total', color='Yellow').set_xticklabels(df['Team'], rotation=90)

# %%
df.nlargest(1,columns='%(win+toss)/total')
# Out:
#                   Team  Win+Toss  Toss  %(win+toss)      %toss  total_matches  \
# 0  Chennai Super Kings        57    89    64.044944  53.614458            166
#
#    %(win+toss)/total
# 0          34.337349

# %%
df.to_csv('team_info.csv')

# %% [markdown]
# #### Team which tops the chart is Chennai Super Kings
#
#
# ### **Question 3**
# * List the names of the **top 10 batsmen** by total runs accumulated across all the seasons
#   * The output should be stored in a list
#
# --------------------------

# %%
batting
# Out:
#         match_no               team_1               team_2        batsmen  \
# 0              1       Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1              1       Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2              1       Mumbai Indians  Chennai Super Kings       S Dhawan
# 3              1       Mumbai Indians  Chennai Super Kings      JP Duminy
# 4              1       Mumbai Indians  Chennai Super Kings       DJ Bravo
# ...          ...                  ...                  ...            ...
# 11541  Final (N)  Chennai Super Kings     Rajasthan Royals      YK Pathan
# 11542  Final (N)  Chennai Super Kings     Rajasthan Royals         M Kaif
# 11543  Final (N)  Chennai Super Kings     Rajasthan Royals      RA Jadeja
# 11544  Final (N)  Chennai Super Kings     Rajasthan Royals       SK Warne
# 11545  Final (N)  Chennai Super Kings     Rajasthan Royals  Sohail Tanvir
#
#                     wicket_status     R     B    M  fours  sixes      SR  \
# ...

# %%
Batsmen=batting['R'].groupby(batting['batsmen']).sum()

# %%
Batsmen.nlargest(10)
# Out:
# batsmen
# V Kohli           5412.0
# SK Raina          5368.0
# RG Sharma         4898.0
# DA Warner         4706.0
# S Dhawan          4579.0
# CH Gayle          4484.0
# MS Dhoni          4432.0
# RV Uthappa        4411.0
# AB de Villiers    4395.0
# G Gambhir         4217.0
# Name: R, dtype: float64

# %%
Top_10=Batsmen.nlargest(10).reset_index()

# %%
Top_10
# Out:
#           batsmen       R
# 0         V Kohli  5412.0
# 1        SK Raina  5368.0
# 2       RG Sharma  4898.0
# 3       DA Warner  4706.0
# 4        S Dhawan  4579.0
# 5        CH Gayle  4484.0
# 6        MS Dhoni  4432.0
# 7      RV Uthappa  4411.0
# 8  AB de Villiers  4395.0
# 9       G Gambhir  4217.0

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(data=top_10,x='batsmen',y='R', color='Pink').set_xticklabels(top_10['batsmen'], rotation=90)
for i,j in enumerate(Top_10['R'].values):
    plt.text(i,j,str(round(j)),ha='center',va='bottom')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 ax=sns.barplot(data=top_10,x='batsmen',y='R', color='Pink').set_xticklabels(top_10['batsmen'], rotation=90)
#       3 for i,j in enumerate(Top_10['R'].values):
#       4     plt.text(i,j,str(round(j)),ha='center',va='bottom')
#
# NameError: name 'top_10' is not defined

# %% [markdown]
# ### Virat Kohli is at top with 5412 runs

# %% [markdown]
# ### **Question 4**
# * Visualize the **runs made vs balls faced** in a jointplot. You should do this for all batsmen who batted in the **IPL season 2017**
#
# --------------------

# %%
batting

# %%
list1=[]
for i in batting['match_date']:
    v=i.split('-')[0]
    list1.append(v.strip())

# %%
batting['year']=list1

# %%
batting

# %%
df=batting[batting['year']=='2017']

# %%
df

# %%
sns.jointplot(x='R',y='B',data=df)

# %% [markdown]
# ### **Question 5**
# * Create a new calculated column called **boundary_contribution**. It is calculated as : **(total runs made in 4s + 6s)/(total runs scored)**
# * Create a scatter-plot between **boundary_contribution** and **strike_rate** where each dot represents an innings by a batsman
# * Aggregate **boundary_contribution** by player and list down **top 10** players by boundary_contribution across all seasons
# ---------------------------------

# %%
df=batting.copy()   # copy

# %%
df['Boundry_contribution']=((df['fours']*4)+(df['sixes']*6))/df['R']*100

# %%
df

# %%
ax=sns.scatterplot(x='Boundry_contribution',y='SR',data=df)

# %%
s1=df['Boundry_contribution'].groupby(df['batsmen']).sum().nlargest(10)

# %%
s1

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(x=s1.index,y=s1.values, color='orange').set_xticklabels(s1.index, rotation=90)
for i,j in enumerate(s1.values):
    plt.text(i,j,str(round(j)),ha='center',va='bottom')

# %% [markdown]
# SK Raina top 10 players by boundary_contribution across all seasons with 9102 Runs

# %% [markdown]
# ### **Question 6**
# * List down **top 10** batsmen by **strike_rate** across all seasons. Plot the top 10 batsmen on a **bar chart**
# * Repeat the above task for **bottom 10** batsmen
# * Create a sub-plot with three sections. Show the below visuals in each :
#   * Box plot of **strike rates** of the top 10 batsmen listed in 1st part of the question
#   * Box plot of **runs scored** of the top 10 batsmen
#   * Box plot of **boundary_contribution** of the top 10 batsmen
# ----------------------------------

# %%
strike_rate=batting['SR'].groupby(batting['batsmen']).agg('sum')

# %%
strike_rate

# %%
strike_rate=strike_rate.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 strike_rate=strike_rate.reset_index()
#
# NameError: name 'strike_rate' is not defined

# %%
strike_rate.sort_values(['SR'],ascending=False,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 strike_rate.sort_values(['SR'],ascending=False,inplace=True)
#
# NameError: name 'strike_rate' is not defined

# %%
df=strike_rate.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 df=strike_rate.head(10)
#
# NameError: name 'strike_rate' is not defined

# %%
df
# Out:
#                            Team  Win+Toss  Toss  %(win+toss)      %toss  \
# 0           Chennai Super Kings        57    89    64.044944  53.614458
# 1               Deccan Chargers        19    43    44.186047  56.578947
# 2                Delhi Capitals        41    90    45.555556  50.561798
# 3                 Gujarat Lions        10    15    66.666667  50.000000
# 4               Kings XI Punjab        34    80    42.500000  45.714286
# 5          Kochi Tuskers Kerala         4     8    50.000000  57.142857
# 6         Kolkata Knight Riders        53    92    57.608696  50.828729
# 7                Mumbai Indians        55    98    56.122449  52.127660
# 8                 Pune Warriors         3    20    15.000000  43.478261
# 9              Rajasthan Royals        41    80    51.250000  53.333333
# 10       Rising Pune Supergiant         8    13    61.538462  43.333333
# 11  Royal Challengers Bangalore        40    82    48.780488  44.808743
# ...

# %%
df=strike_rate.head(10)
df1=strike_rate.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df=strike_rate.head(10)
#       2 df1=strike_rate.tail(10)
#
# NameError: name 'strike_rate' is not defined

# %%
rainbow_colors = sns.color_palette("rainbow", len(df))
ax = sns.barplot(x=df['batsmen'], y=df['SR'],palette=rainbow_colors).set_xticklabels(df['batsmen'], rotation=90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Documents\Python Scripts\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'batsmen'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 2
# ...

# %%
df1

# %%
df1=strike_rate[strike_rate['SR']>0].tail(10)

# %%
rainbow_colors = sns.color_palette("rainbow", len(df))
ax = sns.barplot(x=df1['batsmen'], y=df1['SR'],palette=rainbow_colors).set_xticklabels(df1['batsmen'], rotation=90)

# %%
Total_runs=batting['R'].groupby(batting['batsmen']).sum().nlargest(10)

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
rainbow_colors = sns.color_palette("rainbow", len(df))
ax = sns.boxplot(df['SR'])

plt.subplot(2,2,2)
rainbow_colors = sns.color_palette("rainbow", len(df1))
ax = sns.boxplot(y=df1['SR'])

plt.subplot(2,2,3)
rainbow_colors = sns.color_palette("rainbow", len(df1))
ax = sns.boxplot(Total_runs['R'])

# %% [markdown]
# ## **Question 7**
# * Create a new column called **dismissal_status**. Use the wicket_status column to extract values like **caught, lbw, bowled** etc. and store in dismissal_status column
# * Extract the bowler name from the column **wicket_status** and store in a new column called **bowler_name**
# * Extract fielder name from the **wicket_status** column and store in a new column called **fielder_name**
# * Create a new column called **fielder_involved**. Set it to 1 if a fielder was involved in the dismissal else 0
# * Create a **count plot** of player dismissals across the categories calculated above. Which category stands out from the rest?

# %%
#Q 7 Create a new column called dismissal_status. Use the wicket_status column to extract values like caught, lbw, bowled etc. 
# and store in dismissal_status column
batting['wicket_status'].unique()

# %%
batting['dismissal_mode'].unique()

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
batting['wicket_status']
# Out:
# 0               c Hayden b Thushara
# 1                           not out
# 2                    c Dhoni b Gony
# 3                        c & b Gony
# 4        c Hayden b Joginder Sharma
#                     ...
# 11541               run out (Raina)
# 11542        c Dhoni b Muralitharan
# 11543         c Kapugedera b Morkel
# 11544                       not out
# 11545                       not out
# Name: wicket_status, Length: 11546, dtype: object

# %%
batting.columns
# Out:
# Index(['match_no', 'team_1', 'team_2', 'batsmen', 'wicket_status', 'R', 'B',
#        'M', 'fours', 'sixes', 'SR', 'special_role', 'dismissal_mode',
#        'bowler_name', 'fielder', 'is_fielder_involved', 'match_date'],
#       dtype='object')

# %%
batting['wicket_status']
# Out:
# 0               c Hayden b Thushara
# 1                           not out
# 2                    c Dhoni b Gony
# 3                        c & b Gony
# 4        c Hayden b Joginder Sharma
#                     ...
# 11541               run out (Raina)
# 11542        c Dhoni b Muralitharan
# 11543         c Kapugedera b Morkel
# 11544                       not out
# 11545                       not out
# Name: wicket_status, Length: 11546, dtype: object

# %%
wicket_status = []
for i in batting['wicket_status']:
    if 'lbw' in i:
        wicket_status.append('lbw')
    elif 'run out' in i:
        wicket_status.append('run out')
    elif 'not out' in i:
        wicket_status.append('not out')
    elif 'retired' in i:
        wicket_status.append('retires')
    elif 'hit wicket' in i:
        wicket_status.append('hit wicket')
    elif 'absent' in i:
        wicket_status.append('absent from match/ injured')
    elif 'st ' in i:
        wicket_status.append('stumped')
    elif 'obstructing' in i:
        wicket_status.append('obstructing')
    elif 'b' in i:
        if 'c' in i:
            wicket_status.append('caught and out')
        else:
            wicket_status.append('clean bold')

# %%
batting['dismissal_status']=wicket_status

# %%
batting
# Out:
#         match_no               team_1               team_2        batsmen  \
# 0              1       Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1              1       Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2              1       Mumbai Indians  Chennai Super Kings       S Dhawan
# 3              1       Mumbai Indians  Chennai Super Kings      JP Duminy
# 4              1       Mumbai Indians  Chennai Super Kings       DJ Bravo
# ...          ...                  ...                  ...            ...
# 11541  Final (N)  Chennai Super Kings     Rajasthan Royals      YK Pathan
# 11542  Final (N)  Chennai Super Kings     Rajasthan Royals         M Kaif
# 11543  Final (N)  Chennai Super Kings     Rajasthan Royals      RA Jadeja
# 11544  Final (N)  Chennai Super Kings     Rajasthan Royals       SK Warne
# 11545  Final (N)  Chennai Super Kings     Rajasthan Royals  Sohail Tanvir
#
#                     wicket_status     R     B    M  fours  sixes      SR  \
# ...

# %%
# Extract the bowler name from the column wicket_status and store in a new column called bowler_name

bowler = []
fielder = []
fielder_involved = []
for temp in batting['wicket_status']:
  if 'lbw' in temp or 'hit wicket' in temp:
    name = temp.split("b ",1)[1] 
    bowler.append(name)
    fielder.append('no fielder')
    fielder_involved.append(0)
  elif 'run out' in temp or 'not out' in temp or 'retired' in temp or 'absent' in temp or 'obstructing' in temp:
    bowler.append('no bowler')
    fielder.append('no fielder')
    fielder_involved.append(0)
  elif 'st ' in temp:
    names = temp.split("st ",1)[1] 
    temps = names.split("b ",1)
    sname = temps[0]
    bname = temps[1]
    bowler.append(bname)
    fielder.append(sname)
    fielder_involved.append(1)
  elif 'b ' in temp:
    if 'c ' in temp:
      names = temp.split("c ",1)[1] 
      temps = names.split("b ",1)
      sname = temps[0]
      bname = temps[1]
      bowler.append(bname)
      if sname == "& " or sname == "&":
        fielder.append(bname)
      else:
        fielder.append(sname)
      fielder_involved.append(1)
    else:
      name = temp.split("b ",1)[1] 
      bowler.append(name)
      fielder.append('no fielder')
      fielder_involved.append(0)

# %%
batting['bowler_name_new']=bowler
batting['fielder_name']=fielder
batting['fielder_involved']=fielder_involved

# %%
batting
# Out:
#         match_no               team_1               team_2        batsmen  \
# 0              1       Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1              1       Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2              1       Mumbai Indians  Chennai Super Kings       S Dhawan
# 3              1       Mumbai Indians  Chennai Super Kings      JP Duminy
# 4              1       Mumbai Indians  Chennai Super Kings       DJ Bravo
# ...          ...                  ...                  ...            ...
# 11541  Final (N)  Chennai Super Kings     Rajasthan Royals      YK Pathan
# 11542  Final (N)  Chennai Super Kings     Rajasthan Royals         M Kaif
# 11543  Final (N)  Chennai Super Kings     Rajasthan Royals      RA Jadeja
# 11544  Final (N)  Chennai Super Kings     Rajasthan Royals       SK Warne
# 11545  Final (N)  Chennai Super Kings     Rajasthan Royals  Sohail Tanvir
#
#                     wicket_status     R     B    M  fours  sixes  ...  \
# ...

# %%
# import seaborn as sns
# ax = sns.countplot(x="dismissal_status", data=batting[batting['Year'] =='2011'])
# ax.figure.set_size_inches(15,8)

# %% [markdown]
# Question 8
# Create a dataframe at a player level. Calculate below mentioned metrics :
#
# #50s
# #100s
# #4s
# #6s
# Average
# Assign below points to the players based on the above metrics and calculate the total points earned :
#
# 1 half century = 5 points
# 1 century = 10 points
# 1 four = 2 point
# 1 six = 4 points
# Average > 30 = 20 points
# Average < 30 = 10 points
# Rank the players based on total points earned. Now list down the top 10 batsmen overall across all IPL seasons

# %%
batting
# Out:
#         match_no               team_1               team_2        batsmen  \
# 0              1       Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1              1       Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2              1       Mumbai Indians  Chennai Super Kings       S Dhawan
# 3              1       Mumbai Indians  Chennai Super Kings      JP Duminy
# 4              1       Mumbai Indians  Chennai Super Kings       DJ Bravo
# ...          ...                  ...                  ...            ...
# 11541  Final (N)  Chennai Super Kings     Rajasthan Royals      YK Pathan
# 11542  Final (N)  Chennai Super Kings     Rajasthan Royals         M Kaif
# 11543  Final (N)  Chennai Super Kings     Rajasthan Royals      RA Jadeja
# 11544  Final (N)  Chennai Super Kings     Rajasthan Royals       SK Warne
# 11545  Final (N)  Chennai Super Kings     Rajasthan Royals  Sohail Tanvir
#
#                     wicket_status     R     B    M  fours  sixes  ...  \
# ...

# %%
batting.columns
# Out:
# Index(['match_no', 'team_1', 'team_2', 'batsmen', 'wicket_status', 'R', 'B',
#        'M', 'fours', 'sixes', 'SR', 'special_role', 'dismissal_mode',
#        'bowler_name', 'fielder', 'is_fielder_involved', 'match_date',
#        'dismissal_status', 'bowler_name_new', 'fielder_name',
#        'fielder_involved', '100s', '50s'],
#       dtype='object')

# %%
batting['100s'] = ((batting['R'])/100)
batting['100s'] = batting['100s'].apply(np.floor)
batting['50s'] = ((batting['R']/50) - 2*(batting['100s']))
batting['50s'] = batting['50s'].apply(np.floor)

# %%
batting.head()
# Out:
#   match_no          team_1               team_2        batsmen  \
# 0        1  Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1        1  Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2        1  Mumbai Indians  Chennai Super Kings       S Dhawan
# 3        1  Mumbai Indians  Chennai Super Kings      JP Duminy
# 4        1  Mumbai Indians  Chennai Super Kings       DJ Bravo
#
#                 wicket_status     R     B    M  fours  sixes  ...  \
# 0         c Hayden b Thushara  26.0  20.0  0.0    5.0    0.0  ...
# 1                     not out  59.0  49.0  0.0    7.0    0.0  ...
# 2              c Dhoni b Gony  22.0  21.0  0.0    2.0    0.0  ...
# 3                  c & b Gony   9.0   7.0  0.0    1.0    0.0  ...
# 4  c Hayden b Joginder Sharma   5.0   4.0  0.0    1.0    0.0  ...
#
#        bowler_name     fielder is_fielder_involved  match_date  \
# 0         Thushara      Hayden                   1  2009-04-18
# ...

# %%
runs=batting.groupby(batting['batsmen']).sum()

# %%
runs=runs[['R','B','fours','sixes','SR','100s','50s']]

# %%
times_played=(batting['batsmen'].groupby(batting['batsmen']).agg('count'))

# %%
batting['times_played']=times_played
runs['times_played']=times_played

# %%
average=runs['R']/times_played
runs['average']=average
runs=runs.reset_index()

# %%
runs['points']=runs['fours']*2+runs['sixes']*4+runs['50s']*5+runs['100s']*10

# %%
runs
# Out:
#             batsmen       R       B  fours  sixes        SR  100s   50s  \
# 0    A Ashish Reddy   280.0   193.0   17.0   14.0   3163.89   0.0   0.0
# 1        A Chandila     4.0     7.0    0.0    0.0     66.66   0.0   0.0
# 2          A Chopra    53.0    71.0    7.0    0.0    370.36   0.0   0.0
# 3       A Choudhary    25.0    20.0    1.0    1.0    491.66   0.0   0.0
# 4       A Dananjaya     4.0     5.0    0.0    0.0     80.00   0.0   0.0
# ..              ...     ...     ...    ...    ...       ...   ...   ...
# 513     YV Takawale   192.0   178.0   26.0    3.0   1015.79   0.0   0.0
# 514   Yashpal Singh    47.0    66.0    5.0    0.0    306.11   0.0   0.0
# 515     Younis Khan     3.0     7.0    0.0    0.0     42.85   0.0   0.0
# 516    Yuvraj Singh  2750.0  2120.0  217.0  149.0  14499.23   0.0  13.0
# 517          Z Khan   117.0   141.0   11.0    2.0   2118.89   0.0   0.0
#
#      times_played    average  points
# 0              23  12.173913    90.0
# ...

# %%
runs.loc[runs['average']>30,'points']=runs['points']+20

# %%
runs.loc[runs['average']<30,'points']=runs['points']+10

# %%
runs.head()
# Out:
#           batsmen      R      B  fours  sixes       SR  100s  50s  \
# 0  A Ashish Reddy  280.0  193.0   17.0   14.0  3163.89   0.0  0.0
# 1      A Chandila    4.0    7.0    0.0    0.0    66.66   0.0  0.0
# 2        A Chopra   53.0   71.0    7.0    0.0   370.36   0.0  0.0
# 3     A Choudhary   25.0   20.0    1.0    1.0   491.66   0.0  0.0
# 4     A Dananjaya    4.0    5.0    0.0    0.0    80.00   0.0  0.0
#
#    times_played    average  points
# 0            23  12.173913   100.0
# 1             2   2.000000    10.0
# 2             6   8.833333    24.0
# 3             3   8.333333    16.0
# 4             1   4.000000    10.0

# %% [markdown]
# OR

# %%
# for i,j in enumerate(runs['average']):
#     if j>30:
#         runs.loc[i,'points']=runs.loc[i,'points']+20
#     else:
#         runs.loc[i,'points']=runs.loc[i,'points']+10

# %%
runs=runs.sort_values('points',ascending=False)

# %%
runs['rank']=range(1,len(runs)+1)

# %%
runs
# Out:
#                batsmen       R       B  fours  sixes        SR  100s   50s  \
# 95            CH Gayle  4484.0  2969.0  368.0  326.0  16177.00   6.0  29.0
# 424           SK Raina  5368.0  3915.0  493.0  194.0  22585.81   1.0  38.0
# 487            V Kohli  5412.0  4112.0  480.0  190.0  20030.77   5.0  36.0
# 113          DA Warner  4706.0  3305.0  458.0  181.0  15653.18   4.0  44.0
# 366          RG Sharma  4898.0  3744.0  431.0  194.0  20495.90   1.0  36.0
# ..                 ...     ...     ...    ...    ...       ...   ...   ...
# 381        RS Gavaskar     2.0     8.0    0.0    0.0     25.00   0.0   0.0
# 90             C Nanda     0.0     1.0    0.0    0.0      0.00   0.0   0.0
# 387       Rasikh Salam     5.0     4.0    0.0    0.0    125.00   0.0   0.0
# 87         C Ganapathy     0.0     0.0    0.0    0.0      0.00   0.0   0.0
# 259  M Prasidh Krishna     1.0     7.0    0.0    0.0     20.00   0.0   0.0
#
#      times_played    average  points  rank
# ...

# %%
import seaborn as sns
ax = sns.barplot(y="points",x="batsmen", data=runs.head(10))
ax.figure.set_size_inches(15,8)

# %% [markdown]
# ### **Question 9**
# * Look for a column called **Special_role** to denote if a player is captain or not.
# * **Filter** the dataframe based on if a player is a captain.
# * Pick all the innings by the captains (For **IPL 2017**) and plot a **box and whiskers plot** of **%run_contribution** per captain
#   * Which captain do you think has played **captain's knock** most of the times? (purely going by % contribution to scorecard for now)
# -----------------

# %%
batting[(batting['special_role']=='captaion')]

# %% [markdown]
# ####
# Conclusion
#
#
# This project offers a comprehensive analysis of the Indian Premier League, revealing patterns and trends that have shaped the tournament over the
# years. By examining match data, player performance, and winning strategies, we gain a deeper understanding of the factors contributing to success
# in the IPL. The insights gained from this analysis can be leveraged by teams, players, and stakeholders to make informed decisions and enhance their
# engagement with this popular cricket league.
